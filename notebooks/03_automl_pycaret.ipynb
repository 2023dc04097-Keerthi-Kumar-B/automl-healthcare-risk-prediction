# %% [markdown]
# 1. Install Pycaret & sanity check

# %%
from pycaret.classification import *

# %% [markdown]
# 2. Load dataset in AutoML notebook & verify

# %%
import pandas as pd
df = pd.read_csv("../data/processed/stroke_cleaned.csv")

df.head()
df.info()
df['stroke'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
#  12  bmi_category       5110 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 519.1+ KB
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %% [markdown]
# 3. Initialize PyCaret Setup

# %%
clf_setup = setup(
    data=df,
    target='stroke',
    session_id=42,
    train_size=0.8,
    fold=5,
    normalize=True,
    transformation=True,
    fix_imbalance=True,
    verbose=True
)
# Out:
# <style type="text/css">
# #T_c514a_row9_col1, #T_c514a_row15_col1, #T_c514a_row17_col1, #T_c514a_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c514a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c514a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c514a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c514a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c514a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c514a_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c514a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c514a_row1_col1" class="data row1 col1" >stroke</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c514a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c514a_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c514a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c514a_row3_col1" class="data row3 col1" >(5110, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c514a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c514a_row4_col1" class="data row4 col1" >(8800, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c514a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c514a_row5_col1" class="data row5 col1" >(7778, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c514a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c514a_row6_col1" class="data row6 col1" >(1022, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c514a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c514a_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c514a_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_c514a_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c514a_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_c514a_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c514a_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_c514a_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c514a_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_c514a_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c514a_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_c514a_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c514a_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_c514a_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c514a_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_c514a_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c514a_row15_col0" class="data row15 col0" >Fix imbalance</td>
#       <td id="T_c514a_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c514a_row16_col0" class="data row16 col0" >Fix imbalance method</td>
#       <td id="T_c514a_row16_col1" class="data row16 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c514a_row17_col0" class="data row17 col0" >Transformation</td>
#       <td id="T_c514a_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c514a_row18_col0" class="data row18 col0" >Transformation method</td>
#       <td id="T_c514a_row18_col1" class="data row18 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c514a_row19_col0" class="data row19 col0" >Normalize</td>
#       <td id="T_c514a_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c514a_row20_col0" class="data row20 col0" >Normalize method</td>
#       <td id="T_c514a_row20_col1" class="data row20 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c514a_row21_col0" class="data row21 col0" >Fold Generator</td>
#       <td id="T_c514a_row21_col1" class="data row21 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c514a_row22_col0" class="data row22 col0" >Fold Number</td>
#       <td id="T_c514a_row22_col1" class="data row22 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_c514a_row23_col0" class="data row23 col0" >CPU Jobs</td>
#       <td id="T_c514a_row23_col1" class="data row23 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_c514a_row24_col0" class="data row24 col0" >Use GPU</td>
#       <td id="T_c514a_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_c514a_row25_col0" class="data row25 col0" >Log Experiment</td>
#       <td id="T_c514a_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_c514a_row26_col0" class="data row26 col0" >Experiment Name</td>
#       <td id="T_c514a_row26_col1" class="data row26 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c514a_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_c514a_row27_col0" class="data row27 col0" >USI</td>
#       <td id="T_c514a_row27_col1" class="data row27 col1" >c7b4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 4. Compare Models

# %%
best_model = compare_models(sort='AUC')
# Out:
# <style type="text/css">
# #T_4e0a8 th {
#   text-align: left;
# }
# #T_4e0a8_row0_col0, #T_4e0a8_row0_col1, #T_4e0a8_row0_col3, #T_4e0a8_row0_col4, #T_4e0a8_row1_col0, #T_4e0a8_row1_col1, #T_4e0a8_row1_col2, #T_4e0a8_row1_col3, #T_4e0a8_row1_col4, #T_4e0a8_row1_col5, #T_4e0a8_row1_col6, #T_4e0a8_row1_col7, #T_4e0a8_row2_col0, #T_4e0a8_row2_col1, #T_4e0a8_row2_col2, #T_4e0a8_row2_col3, #T_4e0a8_row2_col4, #T_4e0a8_row2_col5, #T_4e0a8_row2_col6, #T_4e0a8_row2_col7, #T_4e0a8_row3_col0, #T_4e0a8_row3_col1, #T_4e0a8_row3_col2, #T_4e0a8_row3_col3, #T_4e0a8_row3_col4, #T_4e0a8_row3_col5, #T_4e0a8_row3_col6, #T_4e0a8_row3_col7, #T_4e0a8_row4_col0, #T_4e0a8_row4_col1, #T_4e0a8_row4_col2, #T_4e0a8_row4_col3, #T_4e0a8_row4_col5, #T_4e0a8_row4_col6, #T_4e0a8_row4_col7, #T_4e0a8_row5_col0, #T_4e0a8_row5_col1, #T_4e0a8_row5_col2, #T_4e0a8_row5_col3, #T_4e0a8_row5_col4, #T_4e0a8_row5_col5, #T_4e0a8_row5_col6, #T_4e0a8_row5_col7, #T_4e0a8_row6_col0, #T_4e0a8_row6_col1, #T_4e0a8_row6_col2, #T_4e0a8_row6_col4, #T_4e0a8_row6_col5, #T_4e0a8_row6_col6, #T_4e0a8_row6_col7, #T_4e0a8_row7_col0, #T_4e0a8_row7_col1, #T_4e0a8_row7_col2, #T_4e0a8_row7_col3, #T_4e0a8_row7_col4, #T_4e0a8_row7_col5, #T_4e0a8_row7_col6, #T_4e0a8_row7_col7, #T_4e0a8_row8_col0, #T_4e0a8_row8_col1, #T_4e0a8_row8_col2, #T_4e0a8_row8_col3, #T_4e0a8_row8_col4, #T_4e0a8_row8_col5, #T_4e0a8_row8_col6, #T_4e0a8_row8_col7, #T_4e0a8_row9_col0, #T_4e0a8_row9_col1, #T_4e0a8_row9_col2, #T_4e0a8_row9_col3, #T_4e0a8_row9_col4, #T_4e0a8_row9_col5, #T_4e0a8_row9_col6, #T_4e0a8_row9_col7, #T_4e0a8_row10_col0, #T_4e0a8_row10_col1, #T_4e0a8_row10_col2, #T_4e0a8_row10_col3, #T_4e0a8_row10_col4, #T_4e0a8_row10_col5, #T_4e0a8_row10_col6, #T_4e0a8_row10_col7, #T_4e0a8_row11_col0, #T_4e0a8_row11_col1, #T_4e0a8_row11_col2, #T_4e0a8_row11_col3, #T_4e0a8_row11_col4, #T_4e0a8_row11_col5, #T_4e0a8_row11_col6, #T_4e0a8_row11_col7, #T_4e0a8_row12_col0, #T_4e0a8_row12_col1, #T_4e0a8_row12_col2, #T_4e0a8_row12_col3, #T_4e0a8_row12_col4, #T_4e0a8_row12_col5, #T_4e0a8_row12_col6, #T_4e0a8_row12_col7, #T_4e0a8_row13_col0, #T_4e0a8_row13_col2, #T_4e0a8_row13_col3, #T_4e0a8_row13_col4, #T_4e0a8_row13_col5, #T_4e0a8_row13_col6, #T_4e0a8_row13_col7 {
#   text-align: left;
# }
# #T_4e0a8_row0_col2, #T_4e0a8_row0_col5, #T_4e0a8_row0_col6, #T_4e0a8_row0_col7, #T_4e0a8_row4_col4, #T_4e0a8_row6_col3, #T_4e0a8_row13_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4e0a8_row0_col8, #T_4e0a8_row1_col8, #T_4e0a8_row2_col8, #T_4e0a8_row3_col8, #T_4e0a8_row4_col8, #T_4e0a8_row5_col8, #T_4e0a8_row6_col8, #T_4e0a8_row7_col8, #T_4e0a8_row8_col8, #T_4e0a8_row9_col8, #T_4e0a8_row10_col8, #T_4e0a8_row11_col8, #T_4e0a8_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4e0a8_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4e0a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e0a8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4e0a8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4e0a8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4e0a8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4e0a8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4e0a8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4e0a8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4e0a8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_4e0a8_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e0a8_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_4e0a8_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_4e0a8_row0_col1" class="data row0 col1" >0.9215</td>
#       <td id="T_4e0a8_row0_col2" class="data row0 col2" >0.8366</td>
#       <td id="T_4e0a8_row0_col3" class="data row0 col3" >0.2258</td>
#       <td id="T_4e0a8_row0_col4" class="data row0 col4" >0.2130</td>
#       <td id="T_4e0a8_row0_col5" class="data row0 col5" >0.2158</td>
#       <td id="T_4e0a8_row0_col6" class="data row0 col6" >0.1752</td>
#       <td id="T_4e0a8_row0_col7" class="data row0 col7" >0.1768</td>
#       <td id="T_4e0a8_row0_col8" class="data row0 col8" >0.4160</td>
#     </tr>
#     <tr>
#       <th id="T_4e0a8_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_4e0a8_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_4e0a8_row1_col1" class="data row1 col1" >0.9210</td>
#       <td id="T_4e0a8_row1_col2" class="data row1 col2" >0.8365</td>
#       <td id="T_4e0a8_row1_col3" class="data row1 col3" >0.2258</td>
#       <td id="T_4e0a8_row1_col4" class="data row1 col4" >0.2103</td>
#       <td id="T_4e0a8_row1_col5" class="data row1 col5" >0.2147</td>
#       <td id="T_4e0a8_row1_col6" class="data row1 col6" >0.1738</td>
#       <td id="T_4e0a8_row1_col7" class="data row1 col7" >0.1752</td>
#       <td id="T_4e0a8_row1_col8" class="data row1 col8" >0.7040</td>
#     </tr>
#     <tr>
#       <th id="T_4e0a8_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_4e0a8_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_4e0a8_row2_col1" class="data row2 col1" >0.9310</td>
#       <td id="T_4e0a8_row2_col2" class="data row2 col2" >0.8259</td>
#       <td id="T_4e0a8_row2_col3" class="data row2 col3" >0.1355</td>
#       <td id="T_4e0a8_row2_col4" class="data row2 col4" >0.2045</td>
#       <td id="T_4e0a8_row2_col5" class="data row2 col5" >0.1595</td>
#       <td id="T_4e0a8_row2_col6" class="data row2 col6" >0.1256</td>
#       <td id="T_4e0a8_row2_col7" class="data row2 col7" >0.1300</td>
#       <td id="T_4e0a8_row2_col8" class="data row2 col8" >2.1660</td>
#     </tr>
#     <tr>
#       <th id="T_4e0a8_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_4e0a8_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_4e0a8_row3_col1" class="data row3 col1" >0.9440</td>
#       <td id="T_4e0a8_row3_col2" class="data row3 col2" >0.8174</td>
#       <td id="T_4e0a8_row3_col3" class="data row3 col3" >0.0453</td>
#       <td id="T_4e0a8_row3_col4" class="data row3 col4" >0.1850</td>
#       <td id="T_4e0a8_row3_col5" class="data row3 col5" >0.0724</td>
#       <td id="T_4e0a8_row3_col6" class="data row3 col6" >0.0546</td>
#       <td id="T_4e0a8_row3_col7" class="data row3 col7" >0.0695</td>
#       <td id="T_4e0a8_row3_col8" class="data row3 col8" >1.0500</td>
#     </tr>
#     <tr>
#       <th id="T_4e0a8_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_4e0a8_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_4e0a8_row4_col1" class="data row4 col1" >0.9499</td>
#       <td id="T_4e0a8_row4_col2" class="data row4 col2" >0.8169</td>
#       <td id="T_4e0a8_row4_col3" class="data row4 col3" >0.0150</td>
#       <td id="T_4e0a8_row4_col4" class="data row4 col4" >0.2500</td>
#       <td id="T_4e0a8_row4_col5" class="data row4 col5" >0.0281</td>
#       <td id="T_4e0a8_row4_col6" class="data row4 col6" >0.0228</td>
#       <td id="T_4e0a8_row4_col7" class="data row4 col7" >0.0502</td>
#       <td id="T_4e0a8_row4_col8" class="data row4 col8" >2.1200</td>
#     </tr>
#     <tr>
#       <th id="T_4e0a8_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_4e0a8_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4e0a8_row5_col1" class="data row5 col1" >0.9462</td>
#       <td id="T_4e0a8_row5_col2" class="data row5 col2" >0.8131</td>
#       <td id="T_4e0a8_row5_col3" class="data row5 col3" >0.0200</td>
#       <td id="T_4e0a8_row5_col4" class="data row5 col4" >0.1286</td>
#       <td id="T_4e0a8_row5_col5" class="data row5 col5" >0.0346</td>
#       <td id="T_4e0a8_row5_col6" class="data row5 col6" >0.0227</td>
#       <td id="T_4e0a8_row5_col7" class="data row5 col7" >0.0334</td>

# %% [markdown]
# 5. Evaluate AutoML Model

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# 6. Generate predictions and metrics explicitly

# %%
# Generate Predictions
predictions = predict_model(best_model)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2c75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2c75_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e2c75_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e2c75_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e2c75_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e2c75_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e2c75_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e2c75_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e2c75_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2c75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2c75_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_e2c75_row0_col1" class="data row0 col1" >0.9237</td>
#       <td id="T_e2c75_row0_col2" class="data row0 col2" >0.8485</td>
#       <td id="T_e2c75_row0_col3" class="data row0 col3" >0.3600</td>
#       <td id="T_e2c75_row0_col4" class="data row0 col4" >0.2812</td>
#       <td id="T_e2c75_row0_col5" class="data row0 col5" >0.3158</td>
#       <td id="T_e2c75_row0_col6" class="data row0 col6" >0.2760</td>
#       <td id="T_e2c75_row0_col7" class="data row0 col7" >0.2784</td>
#     </tr>
#   </tbody>
# </table>
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 3725  24202    Male  63.0             0              0          Yes   Private
# 4481  66006  Female  43.0             0              0          Yes   Private
# 1545  52089  Female  23.0             0              0           No   Private
# 1820  47608  Female  21.0             0              0           No   Private
# 1262  48781    Male  67.0             0              0          Yes   Private
#
#      Residence_type  avg_glucose_level        bmi   smoking_status  \
# 3725          Rural          78.230003  34.799999     never smoked
# 4481          Urban          86.669998  33.299999     never smoked
# 1545          Urban         126.669998  28.700001           smokes
# 1820          Urban         208.169998  24.900000     never smoked
# 1262          Rural         113.339996  26.299999  formerly smoked
#
#      bmi_category  stroke  prediction_label  prediction_score
# 3725        Obese       0                 0            0.9530
# 4481        Obese       0                 0            0.9830
# 1545   Overweight       0                 0            0.9891
# 1820       Normal       0                 0            0.9960
# 1262   Overweight       0                 0            0.7401

# %%
# Compute ROC-AUC Score
from sklearn.metrics import roc_auc_score

roc_auc_automl = roc_auc_score(
    predictions['stroke'],
    1 - predictions['prediction_score']
)

roc_auc_automl
# Out:
# 0.8318724279835391

# %% [markdown]
# 7. Explainability for LDA using coefficients

# %%
# Extract feature names
X_transformed = get_config('X_train_transformed')
feature_names = X_transformed.columns

# %%
# Extract LDA Coefficients
import pandas as pd
import numpy as np

lda_coefficients = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': best_model.coef_[0]
})

lda_coefficients['Absolute_Coefficient'] = np.abs(lda_coefficients['Coefficient'])

lda_coefficients = lda_coefficients.sort_values(
    by='Absolute_Coefficient',
    ascending=False
)

lda_coefficients.head(10)
# Out:
#                            Feature  Coefficient  Absolute_Coefficient
# 1                    gender_Female     8.688930              8.688930
# 2                      gender_Male     8.651935              8.651935
# 18         bmi_category_Overweight     3.113188              3.113188
# 16              bmi_category_Obese     2.883401              2.883401
# 20     smoking_status_never smoked     2.571308              2.571308
# 23  smoking_status_formerly smoked     2.531425              2.531425
# 22          smoking_status_Unknown     2.397361              2.397361
# 17             bmi_category_Normal     2.272598              2.272598
# 21           smoking_status_smokes     2.223301              2.223301
# 8                work_type_Private     2.061805              2.061805
